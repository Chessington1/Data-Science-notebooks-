# %%
import re

# The string to be searched
text = "abc123"

# Regex pattern with a capturing group for one or more digits
pattern = r"(\d+)"

# Searching the text for the pattern
match = re.search(pattern, text)

# Checking if a match is found
if match:
    # Retrieving the first captured group
    captured_group = match.group(1)
    print("Captured Group:\n", captured_group)
else:
    print("No match found.")
# Out:
# Captured Group:
#  123

# %%
import re

text = "Python is an amazing programming language."
pattern = "amazing"

match = re.search(pattern, text)

if match:
    print("Match found:", match.group())
    print("Match starts at position:", match.start())
else:
    print("No match found.")
# Out:
# Match found: amazing
# Match starts at position: 13

# %%
import re

text = "Python is an amazing programming language."
pattern = "amazing"

match = re.search(pattern, text)

if match:
    print("Match found:", match.group())
    print("Start position:", match.start())
    print("End position:", match.end())
    print("Span (start, end):", match.span())
else:
    print("No match found.")
# Out:
# Match found: amazing
# Start position: 13
# End position: 20
# Span (start, end): (13, 20)

# %%
text ="Python is an amazing programming language."
for i, ch in enumerate(text):
    print(i, repr(ch))
# Out:
# 0 'P'
# 1 'y'
# 2 't'
# 3 'h'
# 4 'o'
# 5 'n'
# 6 ' '
# 7 'i'
# 8 's'
# 9 ' '
# 10 'a'
# 11 'n'
# 12 ' '
# 13 'a'
# 14 'm'
# 15 'a'
# 16 'z'
# 17 'i'
# 18 'n'
# 19 'g'
# 20 ' '
# 21 'p'
# 22 'r'
# 23 'o'
# 24 'g'
# 25 'r'
# 26 'a'
# 27 'm'
# 28 'm'
# 29 'i'
# 30 'n'
# 31 'g'
# 32 ' '
# 33 'l'
# 34 'a'
# 35 'n'
# 36 'g'
# 37 'u'
# 38 'a'
# 39 'g'
# 40 'e'
# 41 '.'

# %%
import re
pattern = "Hello"
text = "Hello, world!"
# Using re.match to find pattern at the start of the text
match = re.match(pattern, text)
if match:
    print("Match found:", match.group())
else:
    print("No match found.")
# Out:
# Match found: Hello

# %%
import re
text = "The dates are 2023-01-01, 2024-02-02"
# Single capturing group
pattern = r"(\d{4}-\d{2}-\d{2})"
# Multiple capturing groups
pattern_multiple = r"(\d{4})-(\d{2})-(\d{2})"
dates = re.findall(pattern, text)
date_parts = re.findall(pattern_multiple, text)
print(dates) # Output: ['2023-01-01', '2024-02-02']
print(date_parts)
# Out:
# ['2023-01-01', '2024-02-02']
# [('2023', '01', '01'), ('2024', '02', '02')]

# %%
import re

text = "The rain in Spain stays mainly in the plain."
pattern = r"\bS\w+"

matches = re.finditer(pattern, text)

for match in matches:
    print(f"Match: {match.group()} at Position: {match.span()}")
# Out:
# Match: Spain at Position: (12, 17)

# %%
text = "The rain in Spain stays mainly in the plain."
for i, ch in enumerate(text):
    print(i, repr(ch))
# Out:
# 0 'T'
# 1 'h'
# 2 'e'
# 3 ' '
# 4 'r'
# 5 'a'
# 6 'i'
# 7 'n'
# 8 ' '
# 9 'i'
# 10 'n'
# 11 ' '
# 12 'S'
# 13 'p'
# 14 'a'
# 15 'i'
# 16 'n'
# 17 ' '
# 18 's'
# 19 't'
# 20 'a'
# 21 'y'
# 22 's'
# 23 ' '
# 24 'm'
# 25 'a'
# 26 'i'
# 27 'n'
# 28 'l'
# 29 'y'
# 30 ' '
# 31 'i'
# 32 'n'
# 33 ' '
# 34 't'
# 35 'h'
# 36 'e'
# 37 ' '
# 38 'p'
# 39 'l'
# 40 'a'
# 41 'i'
# 42 'n'
# 43 '.'

# %%
import re

text = """I love Python. Python is great for scripting.
Python can be used for data analysis."""
pattern = "Python"
replacement = "Java"

# Replace all occurrences of 'Python' with 'Java'
result = re.sub(pattern, replacement, text)
print(result)
# Out:
# I love Java. Java is great for scripting.
# Java can be used for data analysis.

# %%
import re
text = "Words, separated, by, commas (and some spaces)"
pattern = ",\s*" # Comma followed by zero or more spaces
result = re.split(r"(,\s*)", text)
print(result)
# Out:
# ['Words', ', ', 'separated', ', ', 'by', ', ', 'commas (and some spaces)']
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8920\385474372.py:3: SyntaxWarning: invalid escape sequence '\s'
#   pattern = ",\s*" # Comma followed by zero or more spaces

# %%
import re

text = "Words, separated, by, commas (and some spaces)"
pattern = r",\s*"  # ✅ raw string for regex
result = re.split(pattern, text)
print(result)
# Out:
# ['Words', 'separated', 'by', 'commas (and some spaces)']

# %%
# Compile the regex pattern for a simple word match
pattern = re.compile(r'hello')
# Sample text
text = "Hello, world!"
# Using the compiled pattern to search in the text
match = pattern.search(text)
if match:
    print("Match found")
else:
    print("No match found")
# Out:
# No match found
